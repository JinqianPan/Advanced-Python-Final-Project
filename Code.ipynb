# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np

# %% [markdown]
# ## Load data

# %%
# IMPORT RAW DATA
dataframes = []

ls = [2008, 2009, 2010, 2012, 2013, 2014, 2015, 2016]
# ls = [2014]
for year in ls:
# for year in range(2008, 2017):
    filename = f'./data/{year}.csv'
    try: 
        this_data = pd.read_csv(filename)
    except:
        this_data = pd.read_csv(filename, encoding= 'unicode_escape')
  
    if year in range(2011, 2017):
        this_data = this_data.drop(columns=['forceuse'])
    if year in range(2013, 2017):
        this_data = this_data.rename(columns={'dettypCM': 'dettypcm', 
                                              'lineCM': 'linecm', 
                                              'detailCM': 'detailcm'})
    # replace " " to NA
    this_data.replace(" ", pd.NA, inplace=True)
    dataframes.append(this_data)

sqf_data_full = pd.concat(dataframes, ignore_index=True)
sqf_data = sqf_data_full.copy()

# %%
sqf_data
# Out:
#          year  pct  ser_num  datestop timestop recstat inout trhsloc  perobs  \
# 0        2008   42     1044   1012008      130       A     O    <NA>    20.0
# 1        2008  108        3   1012008     2010       A     I    <NA>     1.0
# 2        2008  100       15   1082008      100       A     O       H     2.0
# 3        2008  103      210   1082008     1905       A     O    <NA>     2.0
# 4        2008   71       90   1122008     2125       A     I       H     5.0
# ...       ...  ...      ...       ...      ...     ...   ...     ...     ...
# 2528266  2016  123       88  11262016     1530       1     O       P    30.0
# 2528267  2016  123       89  12022016     1847       1     O       P     1.0
# 2528268  2016  123       90  12022016      255       1     O       P     5.0
# 2528269  2016  123       91  12042016     2225       1     O       P     2.0
# 2528270  2016  123       92  11222016     2212       1     O       P     1.0
#
#           crimsusp  ...  zip addrpct sector  beat  post   xcoord   ycoord  \
# 0              FEL  ...  NaN      42      B  <NA>  <NA>  1009873  0243953
# 1         BURGLARY  ...  NaN     108      B  <NA>  <NA>  1001546  0210784
# 2          ROBBERY  ...  NaN     100      B     2  <NA>  1042944  0154180
# 3          ROBBERY  ...  NaN     103      J    16  <NA>  1050245  0196802
# 4        CRIM-TRES  ...  NaN      71      C     5    PP  0995112  0180043
# ...            ...  ...  ...     ...    ...   ...   ...      ...      ...
# 2528266        FEL  ...  NaN     123      B  <NA>  <NA>   915472   125013
# 2528267        FEL  ...  NaN     123      G  <NA>  <NA>   935054   136263
# 2528268       MISD  ...  NaN     123      B  <NA>  <NA>   917943   127951
# 2528269       MISD  ...  NaN     123      C  <NA>  <NA>   930949   133127
# 2528270       MISD  ...  NaN     123      F  <NA>  <NA>   939042   132823
#
#         dettypcm  linecm  detailcm
# 0             CM       1        20
# 1             CM       1        14
# 2             CM       1        85
# 3             CM       1        85
# 4             CM       1        31
# ...          ...     ...       ...
# 2528266       CM       1        14
# 2528267       CM       1         9
# 2528268       CM       1        80
# 2528269       CM       1        68
# 2528270       CM       1        20
#
# [2528271 rows x 111 columns]

# %%
column_names = ['year', 'pistol', 'riflshot', 'asltweap', 'machgun', 'knifcuti', 'othrweap',
                'pct', 'trhsloc', 
                'ac_assoc', 'ac_cgdir', 'ac_rept', 'ac_evasv', 'ac_incid', 
                'ac_inves', 'ac_proxm', 'ac_time', 'ac_stsnd', 'ac_other',
                'cs_objcs', 'cs_descr', 'cs_casng', 'cs_lkout', 'cs_cloth', 'cs_drgtr', 
                'cs_furtv', 'cs_vcrim', 'cs_bulge', 'cs_other', 'age', 'build', 'sex', 
                'ht_feet', 'ht_inch', 'weight', 'inout', 'radio', 'perobs', 'datestop', 'timestop']

# %%
sqf_data = sqf_data[column_names]

# %%
sqf_data
# Out:
#          year pistol riflshot asltweap machgun knifcuti othrweap  pct trhsloc  \
# 0        2008      N        N        N       N        N        N   42    <NA>
# 1        2008      N        N        N       N        N        N  108    <NA>
# 2        2008      N        N        N       N        N        N  100       H
# 3        2008      N        N        N       N        N        N  103    <NA>
# 4        2008      N        N        N       N        N        N   71       H
# ...       ...    ...      ...      ...     ...      ...      ...  ...     ...
# 2528266  2016      N        N        N       N        N        N  123       P
# 2528267  2016      N        N        N       N        N        N  123       P
# 2528268  2016      N        N        N       N        N        N  123       P
# 2528269  2016      N        N        N       N        N        N  123       P
# 2528270  2016      N        N        N       N        N        Y  123       P
#
#         ac_assoc  ... build sex ht_feet ht_inch weight inout radio perobs  \
# 0              N  ...     U   M       6       0    161     O     N   20.0
# 1              N  ...     H   M       5       7    190     I     Y    1.0
# 2              N  ...     M   M       6       0    180     O     N    2.0
# 3              N  ...     M   M       6       1    185     O     N    2.0
# 4              N  ...     T   M       5       9    145     I     N    5.0
# ...          ...  ...   ...  ..     ...     ...    ...   ...   ...    ...
# 2528266        N  ...     M   M       5       7    160     O     Y   30.0
# 2528267        N  ...     M   M       5      11    210     O     Y    1.0
# 2528268        N  ...     Z   M       5       8    140     O     N    5.0
# 2528269        N  ...     T   M       5      10    185     O     Y    2.0
# 2528270        N  ...     M   M       4      10    160     O     Y    1.0
#
#          datestop timestop
# 0         1012008      130
# 1         1012008     2010
# 2         1082008      100
# 3         1082008     1905
# 4         1122008     2125
# ...           ...      ...
# 2528266  11262016     1530
# 2528267  12022016     1847
# 2528268  12022016      255
# 2528269  12042016     2225
# 2528270  11222016     2212
#
# [2528271 rows x 40 columns]

# %%
sqf_data[pd.isna(sqf_data['timestop'])].index

sqf_data['datestop'] = sqf_data['datestop'].apply(lambda x: '{0:0>8}'.format(x))
sqf_data['timestop'] = sqf_data['timestop'].apply(lambda x: '{0:0>4}'.format(x))

sqf_data['month'] = sqf_data['datestop'].str[:2].astype(int)
sqf_data['day'] = sqf_data['datestop'].str[2:4].astype(int)
sqf_data['year'] = sqf_data['year'].astype(int)

sqf_data['time_period'] = sqf_data['timestop'].str[:2].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 10
#       7 sqf_data['day'] = sqf_data['datestop'].str[2:4].astype(int)
#       8 sqf_data['year'] = sqf_data['year'].astype(int)
# ---> 10 sqf_data['time_period'] = sqf_data['timestop'].str[:2].astype(int)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '<N'

# %%
## Handle 2014

coln = ["cs_objcs", "cs_descr", "cs_casng","cs_lkout", "cs_cloth", 
        "cs_drgtr", "cs_furtv", "cs_vcrim", "cs_bulge", "cs_other",
        "ac_rept", "ac_inves", "ac_proxm", "ac_evasv", "ac_assoc", "ac_cgdir",
        "ac_incid", "ac_time", "ac_stsnd", "ac_other", "pistol", "riflshot", "asltweap", 
        "knifcuti", "machgun", "othrweap"]

# replace values for 2014 and convert to 'Y' or 'N'
for i in coln:
    sqf_data.loc[(sqf_data['year'] == 2014) & (sqf_data[i] == 1), i] = 'Y'
    sqf_data.loc[(sqf_data['year'] == 2014) & (sqf_data[i].isna()), i] = 'N'

# %%
# 'pistol', 'riflshot', 'asltweap', 'machgun', 'knifcuti', 'othrweap'

def recode_yn(f):
    f_new = f.replace({'N': 0, 'Y': 1})
    f_new = f_new.astype(bool)
    return f_new

sqf_data = sqf_data.assign(found_pistol = recode_yn(sqf_data['pistol']),
                           found_rifle = recode_yn(sqf_data['riflshot']),
                           found_assault = recode_yn(sqf_data['asltweap']),
                           found_machinegun = recode_yn(sqf_data['machgun']),
                           found_knife = recode_yn(sqf_data['knifcuti']),
                           found_other = recode_yn(sqf_data['othrweap']))

sqf_data['found_weapon'] = (sqf_data['found_pistol'] | sqf_data['found_rifle'] |
                            sqf_data['found_assault'] | sqf_data['found_machinegun'] |
                            sqf_data['found_knife'] | sqf_data['found_other'])

# %%
sqf_data
# Out:
#          year pistol riflshot asltweap machgun knifcuti othrweap  pct trhsloc  \
# 0        2008      N        N        N       N        N        N   42    <NA>
# 1        2008      N        N        N       N        N        N  108    <NA>
# 2        2008      N        N        N       N        N        N  100       H
# 3        2008      N        N        N       N        N        N  103    <NA>
# 4        2008      N        N        N       N        N        N   71       H
# ...       ...    ...      ...      ...     ...      ...      ...  ...     ...
# 2528266  2016      N        N        N       N        N        N  123       P
# 2528267  2016      N        N        N       N        N        N  123       P
# 2528268  2016      N        N        N       N        N        N  123       P
# 2528269  2016      N        N        N       N        N        N  123       P
# 2528270  2016      N        N        N       N        N        Y  123       P
#
#         ac_assoc  ... timestop month day found_pistol found_rifle  \
# 0              N  ...     0130     1   1        False       False
# 1              N  ...     2010     1   1        False       False
# 2              N  ...     0100     1   8        False       False
# 3              N  ...     1905     1   8        False       False
# 4              N  ...     2125     1  12        False       False
# ...          ...  ...      ...   ...  ..          ...         ...
# 2528266        N  ...     1530    11  26        False       False
# 2528267        N  ...     1847    12   2        False       False
# 2528268        N  ...     0255    12   2        False       False
# 2528269        N  ...     2225    12   4        False       False
# 2528270        N  ...     2212    11  22        False       False
#
#         found_assault found_machinegun found_knife found_other found_weapon
# 0               False            False       False       False        False
# 1               False            False       False       False        False
# 2               False            False       False       False        False
# 3               False            False       False       False        False
# 4               False            False       False       False        False
# ...               ...              ...         ...         ...          ...
# 2528266         False            False       False       False        False
# 2528267         False            False       False       False        False
# 2528268         False            False       False       False        False
# 2528269         False            False       False       False        False
# 2528270         False            False       False        True         True
#
# [2528271 rows x 49 columns]

# %%
sqf_data = sqf_data.assign(precinct=pd.factorize(sqf_data['pct'])[0]+1)

# %%
# create dictionary for recoding
recode_dict = {'P': 'neither', 'H': 'housing', 'T': 'transit'}

# add new column to sqf_data
sqf_data['location.housing'] = sqf_data_full['trhsloc'].replace(recode_dict).fillna('neither')

# %%
sqf_data = sqf_data.assign(additional_associating = recode_yn(sqf_data['ac_assoc']),
                           additional_direction = recode_yn(sqf_data['ac_cgdir']),
                           additional_report = recode_yn(sqf_data['ac_rept']),
                           additional_evasive = recode_yn(sqf_data['ac_evasv']),
                           additional_highcrime = recode_yn(sqf_data['ac_incid']),
                           additional_investigation = recode_yn(sqf_data['ac_inves']),
                           additional_proximity = recode_yn(sqf_data['ac_proxm']),
                           additional_time = recode_yn(sqf_data['ac_time']),
                           additional_sights = recode_yn(sqf_data['ac_stsnd']),
                           additional_other = recode_yn(sqf_data['ac_other']))

# %%
sqf_data
# Out:
#          year pistol riflshot asltweap machgun knifcuti othrweap  pct trhsloc  \
# 0        2008      N        N        N       N        N        N   42    <NA>
# 1        2008      N        N        N       N        N        N  108    <NA>
# 2        2008      N        N        N       N        N        N  100       H
# 3        2008      N        N        N       N        N        N  103    <NA>
# 4        2008      N        N        N       N        N        N   71       H
# ...       ...    ...      ...      ...     ...      ...      ...  ...     ...
# 2528266  2016      N        N        N       N        N        N  123       P
# 2528267  2016      N        N        N       N        N        N  123       P
# 2528268  2016      N        N        N       N        N        N  123       P
# 2528269  2016      N        N        N       N        N        N  123       P
# 2528270  2016      N        N        N       N        N        Y  123       P
#
#         ac_assoc  ... additional_associating additional_direction  \
# 0              N  ...                  False                False
# 1              N  ...                  False                False
# 2              N  ...                  False                False
# 3              N  ...                  False                False
# 4              N  ...                  False                False
# ...          ...  ...                    ...                  ...
# 2528266        N  ...                  False                False
# 2528267        N  ...                  False                False
# 2528268        N  ...                  False                False
# 2528269        N  ...                  False                False
# 2528270        N  ...                  False                False
#
#         additional_report additional_evasive additional_highcrime  \
# 0                   False               True                False
# 1                   False              False                False
# 2                    True              False                False
# 3                   False               True                 True
# 4                   False              False                 True
# ...                   ...                ...                  ...
# 2528266             False              False                False
# 2528267             False              False                False
# 2528268             False              False                False
# 2528269             False              False                False
# 2528270             False              False                False
#
#         additional_investigation additional_proximity additional_time  \
# 0                          False                False           False
# 1                          False                 True           False
# 2                          False                 True            True
# 3                          False                False           False
# 4                          False                False            True
# ...                          ...                  ...             ...
# 2528266                    False                False           False
# 2528267                    False                 True           False
# 2528268                    False                 True           False
# 2528269                    False                False           False
# 2528270                    False                False           False
#
#         additional_sights additional_other
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 2528266             False            False
# 2528267             False            False
# 2528268             False            False
# 2528269             False            False
# 2528270             False            False
#
# [2528271 rows x 61 columns]

# %%
sqf_data = sqf_data.assign(stopped_bulge = recode_yn(sqf_data['cs_objcs']),
                           stopped_object = recode_yn(sqf_data['cs_descr']),
                           stopped_casing = recode_yn(sqf_data['cs_casng']),
                           stopped_clothing = recode_yn(sqf_data['cs_lkout']),
                           stopped_desc = recode_yn(sqf_data['cs_cloth']),
                           stopped_drugs = recode_yn(sqf_data['cs_drgtr']),
                           stopped_furtive = recode_yn(sqf_data['cs_furtv']),
                           stopped_lookout = recode_yn(sqf_data['cs_vcrim']),
                           stopped_violent = recode_yn(sqf_data['cs_bulge']),
                           stopped_other = recode_yn(sqf_data['cs_other']))

# %%
sqf_data
# Out:
#          year pistol riflshot asltweap machgun knifcuti othrweap  pct trhsloc  \
# 0        2008      N        N        N       N        N        N   42    <NA>
# 1        2008      N        N        N       N        N        N  108    <NA>
# 2        2008      N        N        N       N        N        N  100       H
# 3        2008      N        N        N       N        N        N  103    <NA>
# 4        2008      N        N        N       N        N        N   71       H
# ...       ...    ...      ...      ...     ...      ...      ...  ...     ...
# 2528266  2016      N        N        N       N        N        N  123       P
# 2528267  2016      N        N        N       N        N        N  123       P
# 2528268  2016      N        N        N       N        N        N  123       P
# 2528269  2016      N        N        N       N        N        N  123       P
# 2528270  2016      N        N        N       N        N        Y  123       P
#
#         ac_assoc  ... stopped_bulge stopped_object stopped_casing  \
# 0              N  ...         False           True          False
# 1              N  ...         False          False          False
# 2              N  ...         False           True          False
# 3              N  ...         False          False          False
# 4              N  ...         False          False          False
# ...          ...  ...           ...            ...            ...
# 2528266        N  ...         False          False          False
# 2528267        N  ...         False           True          False
# 2528268        N  ...         False           True          False
# 2528269        N  ...         False           True          False
# 2528270        N  ...         False           True          False
#
#         stopped_clothing stopped_desc stopped_drugs stopped_furtive  \
# 0                  False        False         False            True
# 1                  False        False         False           False
# 2                  False        False         False           False
# 3                   True        False         False            True
# 4                   True        False         False           False
# ...                  ...          ...           ...             ...
# 2528266             True        False         False           False
# 2528267            False        False         False           False
# 2528268            False        False         False           False
# 2528269            False        False         False           False
# 2528270            False        False         False           False
#
#         stopped_lookout stopped_violent stopped_other
# 0                 False           False          True
# 1                 False           False          True
# 2                 False           False         False
# 3                 False           False         False
# 4                 False           False          True
# ...                 ...             ...           ...
# 2528266           False           False         False
# 2528267           False           False         False
# 2528268           False           False         False
# 2528269           False           False         False
# 2528270           False           False         False
#
# [2528271 rows x 71 columns]

# %%
# add new column to sqf_data
try:
    sqf_data['age'] = sqf_data['age'].replace('**', -1)
    sqf_data['suspect_age'] = sqf_data['age'].fillna(-1).astype(int).replace('-1', pd.NA)
except:
    sqf_data['suspect_age'] = sqf_data['age'].fillna(-1).astype(int).replace('-1', pd.NA)

# replace suspect.age > 100 with NA
sqf_data.loc[sqf_data['suspect_age'] > 100, 'suspect_age'] = pd.NA
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       2 try:
# ----> 3     sqf_data['age'] = sqf_data['age'].replace('**', -1)
#       4     sqf_data['suspect_age'] = sqf_data['age'].fillna(-1).astype(int).replace('-1', pd.NA)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/series.py:5380, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    5362 @deprecate_nonkeyword_arguments(
#    5363     version=None, allowed_args=["self", "to_replace", "value"]
#    5364 )
#    (...)
#    5378     method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5379 ) -> Series | None:
# -> 5380     return super().replace(
#    5381         to_replace=to_replace,
#    5382         value=value,
#    5383         inplace=inplace,
#    5384         limit=limit,
#    5385         regex=regex,
#    5386         method=method,
#    5387     )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py:7280, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7279     else:
# -> 7280         new_data = self._mgr.replace(
#    7281             to_replace=to_replace, value=value, inplace=inplace
#    7282         )
#    7283 else:
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:472, in BaseBlockManager.replace(self, to_replace, value, inplace)
#     471 assert not is_list_like(value)
# --> 472 return self.apply(
#     473     "replace", to_replace=to_replace, value=value, inplace=inplace
#     474 )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/blocks.py:592, in Block.replace(self, to_replace, value, inplace, mask)
#     591 if mask is None:
# --> 592     mask = missing.mask_missing(values, to_replace)
#     593 if not mask.any():
#     594     # Note: we get here with test_replace_extension_other incorrectly
#     595     #  bc _can_hold_element is incorrect.
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/missing.py:98, in mask_missing(arr, values_to_mask)
#      96 if not isinstance(new_mask, np.ndarray):
#      97     # usually BooleanArray
# ---> 98     new_mask = new_mask.to_numpy(dtype=bool, na_value=False)
#      99 mask |= new_mask
#
# AttributeError: 'bool' object has no attribute 'to_numpy'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       4     sqf_data['suspect_age'] = sqf_data['age'].fillna(-1).astype(int).replace('-1', pd.NA)
#       5 except:
# ----> 6     sqf_data['suspect_age'] = sqf_data['age'].fillna(-1).astype(int).replace('-1', pd.NA)
#       8 # replace suspect.age > 100 with NA
#       9 sqf_data.loc[sqf_data['suspect_age'] > 100, 'suspect_age'] = pd.NA
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '**'

# %%
# create dictionary for recoding
recode_dict = {'H': 'heavy', 'M': 'medium', 'T': 'thin', 'U': 'muscular', 'Z': 'unknown'}

# add new column to sqf_data
sqf_data['suspect.build'] = sqf_data['build'].replace(recode_dict)

# %%
# create dictionary for recoding
recode_dict = {'M': 'male', 'F': 'female'}

# add new column to sqf_data
sqf_data['suspect.sex'] = sqf_data['sex'].replace(recode_dict)

# %%
sqf_data['suspect_height'] = sqf_data['ht_feet'] + (sqf_data['ht_inch'] / 12)

# %%
# add new column to sqf_data
sqf_data['suspect_weight'] = sqf_data['weight']

# %%
def recode_io(f):
    f_new = f.replace({'O': 0, 'I': 1})
    f_new = f_new.astype(bool)
    return f_new

sqf_data['inside'] = recode_io(sqf_data['inout'])
sqf_data['observation_period'] = sqf_data['perobs']

# %%
sqf_data = sqf_data.assign(radio_run = recode_yn(sqf_data['radio']))

# %%
sqf_data = sqf_data.drop(columns=column_names)

# %%
tmp_col_names = ['found_pistol', 'found_rifle', 'found_assault', 
                 'found_machinegun', 'found_knife', 'found_other']

# %%
sqf_data = sqf_data.drop(columns=tmp_col_names)

# %%
sqf_data
# Out:
#          month  day  found_weapon  precinct location.housing  \
# 0            1    1         False         1          neither
# 1            1    1         False         2          neither
# 2            1    8         False         3          housing
# 3            1    8         False         4          neither
# 4            1   12         False         5          housing
# ...        ...  ...           ...       ...              ...
# 2528266     11   26         False        56          neither
# 2528267     12    2         False        56          neither
# 2528268     12    2         False        56          neither
# 2528269     12    4         False        56          neither
# 2528270     11   22          True        56          neither
#
#          additional_associating  additional_direction  additional_report  \
# 0                         False                 False              False
# 1                         False                 False              False
# 2                         False                 False               True
# 3                         False                 False              False
# 4                         False                 False              False
# ...                         ...                   ...                ...
# 2528266                   False                 False              False
# 2528267                   False                 False              False
# 2528268                   False                 False              False
# 2528269                   False                 False              False
# 2528270                   False                 False              False
#
#          additional_evasive  additional_highcrime  ...  stopped_lookout  \
# 0                      True                 False  ...            False
# 1                     False                 False  ...            False
# 2                     False                 False  ...            False
# 3                      True                  True  ...            False
# 4                     False                  True  ...            False
# ...                     ...                   ...  ...              ...
# 2528266               False                 False  ...            False
# 2528267               False                 False  ...            False
# 2528268               False                 False  ...            False
# 2528269               False                 False  ...            False
# 2528270               False                 False  ...            False
#
#          stopped_violent  stopped_other  suspect.build  suspect.sex  \
# 0                  False           True       muscular         male
# 1                  False           True          heavy         male
# 2                  False          False         medium         male
# 3                  False          False         medium         male
# 4                  False           True           thin         male
# ...                  ...            ...            ...          ...
# 2528266            False          False         medium         male
# 2528267            False          False         medium         male
# 2528268            False          False        unknown         male
# 2528269            False          False           thin         male
# 2528270            False          False         medium         male
#
#          suspect_height  suspect_weight  inside  observation_period  radio_run
# 0              6.000000             161   False                20.0      False
# 1              5.583333             190    True                 1.0       True
# 2              6.000000             180   False                 2.0      False
# 3              6.083333             185   False                 2.0      False
# 4              5.750000             145    True                 5.0      False
# ...                 ...             ...     ...                 ...        ...
# 2528266        5.583333             160   False                30.0       True
# 2528267        5.916667             210   False                 1.0       True
# 2528268        5.666667             140   False                 5.0      False
# 2528269        5.833333             185   False                 2.0       True
# 2528270        4.833333             160   False                 1.0       True
#
# [2528271 rows x 32 columns]

# %%
sqf_data.isna().any()
# Out:
# month                       False
# day                         False
# found_weapon                False
# precinct                    False
# location.housing            False
# additional_associating      False
# additional_direction        False
# additional_report           False
# additional_evasive          False
# additional_highcrime        False
# additional_investigation    False
# additional_proximity        False
# additional_time             False
# additional_sights           False
# additional_other            False
# stopped_bulge               False
# stopped_object              False
# stopped_casing              False
# stopped_clothing            False
# stopped_desc                False
# stopped_drugs               False
# stopped_furtive             False
# stopped_lookout             False
# stopped_violent             False
# stopped_other               False
# suspect.build               False
# suspect.sex                 False
# suspect_height              False
# suspect_weight              False
# inside                      False
# observation_period          False
# radio_run                   False
# dtype: bool
